# %%
#Imports
from sklearn import tree
from sklearn.tree import export_graphviz 
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier

# %%
#Data Loading
iris = load_iris()
X = iris.data[:,2:]
y = iris.target

# %%
#Model
clf = DecisionTreeClassifier()
clf.fit(X,y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
#Exporting Tree image to directory
export_graphviz(clf,out_file='tree.dot',
                feature_names=iris.feature_names[2:],
                class_names=iris.target_names,
                rounded=True,filled=True)

# %% [markdown]
# - type dot -Tpng tree.dot -o tree.png in command prompt in the same directory where your notebook is saved.

# %%
#Importing Image on Jupyter notebook
from IPython.display import Image
Image('tree.png',height='300',width='480')
